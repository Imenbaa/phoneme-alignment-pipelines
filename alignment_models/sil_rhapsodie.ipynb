# %%
# !python cut_SIL.py /vol/corpora/TAPAS_FRAIS/Data_partagees_ParisTypaloc-TapasFrais/12-SLA/PHO-307175-01_L01_pr_analyse.TextGrid --tier corr-FI --wav /vol/corpora/TAPAS_FRAIS/Data_partagees_ParisTypaloc-TapasFrais/12-SLA/PHO-307175-01_L01.wav --outdir chunks/ --csv chunks.csv
# Out:
# chunk     start       end       dur  phones
# 1         0.780     7.429     6.649      75  dd an zz in pp eu tt ii vv ii ll aa jj dd eu ll aa #a dd an #a dd an zz in pp eu tt ii vv ii ll aa jj dd eu ll aa mm on tt aa gn #a ii ll ii aa #a in pp oo vv rr eu kk au rr dd au nn yy ei tt ou vv yy eu aa tt ou kk aa ss ei
# 2        11.200    15.290     4.090      52  ll ei vv ii ll aa jj ww aa ll uy ii aa pp oo rr tt eu dd ai ch oo ss uu rr aa rr ai pp aa rr ei #a mm ei ii ll nn eu tt rr aa vv aa yy pp aa #a vv ii tt eu
# 3        15.590    17.800     2.210      30  tt ou ll ai ss ww aa rr ii ll mm an jj eu tt ou ss oe ll bb yy in tt rr ii ss tt eu mm an
# 4        18.788    21.535     2.747      33  ss eu ss ww aa rr #a ii ll ii aa dd eu vv an ll uy ii in gg rr au tt aa dd eu ss ou yy ei ei dd eu
# 5        22.069    23.410     1.341      13  gg ai tt rr #a aa rr eu kk ou dd rr oe
# ...
