# %%
import pandas as pd
data_dir="/vol/experiments2/cbrazier/transcription/datasets/ester1_ester2_epac"
df = pd.read_csv(data_dir+"/test/metadata.csv")

# %%
df
# Out:
#                                              file_name  \
# 0       20071218_1900_1920_inter-00011731-00012743.wav
# 1       20071218_1900_1920_inter-00012743-00014543.wav
# 2       20071218_1900_1920_inter-00021481-00022860.wav
# 3       20071218_1900_1920_inter-00025047-00032585.wav
# 4       20071218_1900_1920_inter-00032585-00040471.wav
# ...                                                ...
# 6188  20080212_1200_1210_africa1-00571259-00575237.wav
# 6189  20080212_1200_1210_africa1-00575237-00580765.wav
# 6190  20080212_1200_1210_africa1-00580765-00583512.wav
# 6191  20080212_1200_1210_africa1-00583512-00590896.wav
# 6192  20080212_1200_1210_africa1-00597484-00601977.wav
#
#                                           transcription  \
# 0                                   il est vingt heures
# 1                à johannesburg dix neuf heures à paris
# 2                         denis astagneau bonsoir denis
# 3     pouvoir d'achat moins trente cinq heures égal ...
# 4     le paiement des jours de réduction du temps de...
# ...                                                 ...
# 6188  issa hayatou le président de la confédération ...
# 6189  voilà pour euh ces nouvelles alors qu'il est o...
# 6190  la rédaction vous revient dans cinquante minut...
# 6191  à paris avec aïssatta et fanny euh ici à libre...
# 6192  merci beaucoup euh très bonne journée à vous d...
#
#                                                phonemes  \
# 0                               i|l| |ɛ| |v|ɛ̃| |œ|ʁ| |
# 1     a| |ʒ|o|a|n|ɛ|z|b|y|ʁ|ɡ| |d|i|z| |n|œ|v| |œ|ʁ|...
# 2     d|ə|n|i| |a|s|t|a|n|j|o| |b|ɔ̃|s|w|a|ʁ| |d|ə|n...
# 3     p|u|v|w|a|ʁ| |d|a|ʃ|a| |m|w|ɛ̃| |t|ʁ|ɑ̃|t| |s|...
# 4     l|ə| |p|ɛ|m|ɑ̃| |d|e| |ʒ|u|ʁ| |d|ə| |ʁ|e|d|y|k...
# ...                                                 ...
# 6188  i|s|a| |ɛ|j|a|t|u| |l|ə| |p|ʁ|e|z|i|d|ɑ̃| |d|ə...
# 6189  v|w|a|l|a| |p|u|ʁ| |œ| |s|e| |n|u|v|ɛ|l|z| |a|...
# 6190  l|a| |ʁ|e|d|a|k|s|j|ɔ̃| |v|u| |ʁ|ə|v|j|ɛ̃| |d|...
# 6191  a| |p|a|ʁ|i| |a|v|ɛ|k| |a|i|s|a|t|a| |e| |f|a|...
# 6192  m|ɛ|ʁ|s|i| |b|o|k|u|p| |œ| |t|ʁ|ɛ| |b|ɔ|n| |ʒ|...
#
#                                         phonemes_single  \
# 0                                           il ɛ v1 9ʁ
# 1                      a ʒoanɛzbyʁɡ diz n9v 9ʁz a paʁi
# 2                             dəni astanjo b§swaʁ dəni
# 3     puvwaʁ daʃa mw1 tʁ@t s1k 9ʁz eɡal ʁaʃa dez ɛʁt...
# 4     lə pɛm@ de ʒuʁ də ʁedyksj§ dy t@ də tʁavaj ɛt ...
# ...                                                 ...
# 6188  isa ɛjatu lə pʁezid@ də la k§fedeʁasj§ afʁikɛn...
# 6189  vwala puʁ 9 se nuvɛlz alɔʁ kil ɛ §z 9ʁz 9 e n9...
# 6190       la ʁedaksj§ vu ʁəvj1 d@ s1k@t minytz @tʁ t@
# 6191  a paʁi avɛk aisata e fani 9 isi a libʁəvil lə ...
# 6192  mɛʁsi bokup 9 tʁɛ bɔn ʒuʁne a vu dy kote də li...
#
#                                       phoneme_single_v1  \
# 0                                         i l ɛ v 5 9 ʁ
# 1     a ʒ o a n ɛ z b y ʁ ɡ d i z n 9 v 9 ʁ z a p a ʁ i
# 2             d ə n i a s t a n j o b § s w a ʁ d ə n i
# 3     p u v w a ʁ d a ʃ a m w 5 t ʁ @ ts 5 k 9 ʁ z e...
# 4     l ə p ɛ m @ d e ʒ u ʁ d ə ʁ e d y k s j § d y ...
# ...                                                 ...
# 6188  i s a ɛ j a t u l ə p ʁ e z i d @ d ə l a k § ...
# 6189  v w a l a p u ʁ 9 s e n u v ɛ l z a l ɔ ʁ k i ...
# 6190  l a ʁ e d a k s j § v u ʁ ə v j 5 d @ s 5 k @ ...
# 6191  a p a ʁ i a v ɛ k a i s a t a e f a n i 9 i s ...
# 6192  m ɛ ʁ s i b o k u p 9 t ʁ ɛ b ɔ n ʒ u ʁ n e a ...
#
#                                      phonemes_single_v2
# 0                                         i l ɛ v 1 9 ʁ
# 1     a ʒ o a n ɛ z b y ʁ ɡ d i z n 9 v 9 ʁ z a p a ʁ i
# 2             d ə n i a s t a n j o b § s w a ʁ d ə n i
# 3     p u v w a ʁ d a ʃ a m w 1 t ʁ @ t s 1 k 9 ʁ z ...
# 4     l ə p ɛ m @ d e ʒ u ʁ d ə ʁ e d y k s j § d y ...
# ...                                                 ...
# 6188  i s a ɛ j a t u l ə p ʁ e z i d @ d ə l a k § ...
# 6189  v w a l a p u ʁ 9 s e n u v ɛ l z a l ɔ ʁ k i ...
# 6190  l a ʁ e d a k s j § v u ʁ ə v j 1 d @ s 1 k @ ...
# 6191  a p a ʁ i a v ɛ k a i s a t a e f a n i 9 i s ...
# 6192  m ɛ ʁ s i b o k u p 9 t ʁ ɛ b ɔ n ʒ u ʁ n e a ...
#
# [6193 rows x 6 columns]
